# %%
import os
from google.colab import userdata
os.environ["HF_TOKEN"] = userdata.get('HF_TOKEN')

# %%
# !pip3 install -q -U bitsandbytes==0.42.0
# !pip3 install -q -U peft==0.8.2
# !pip3 install -q -U trl==0.7.10
# !pip3 install -q -U accelerate==0.27.1
# !pip3 install -q -U datasets==2.17.0
# !pip3 install -q -U transformers==4.38.0
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.0/105.0 MB 5.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.4/183.4 kB 5.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.6/297.6 kB 32.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.9/150.9 kB 3.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 46.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.0/102.0 kB 13.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 14.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 25.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 19.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.9/388.9 kB 41.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 279.7/279.7 kB 6.5 MB/s eta 0:00:00
# ...

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig, GemmaTokenizer

model_id = "google/gemma-2b"
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)

tokenizer = AutoTokenizer.from_pretrained(model_id, token=os.environ['HF_TOKEN'])
# Out:
# tokenizer_config.json:   0%|          | 0.00/33.6k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]

# %%
model = AutoModelForCausalLM.from_pretrained(model_id,
                                             quantization_config=bnb_config,
                                             device_map={"":0},
                                             token=os.environ['HF_TOKEN'])
# Out:
# config.json:   0%|          | 0.00/627 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/13.5k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/67.1M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]

# %%
text = "Quote: With great power"
device = "cuda:0"
inputs = tokenizer(text, return_tensors="pt").to(device)

outputs = model.generate(**inputs, max_new_tokens=20)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# Quote: With great power comes great responsibility.
#
# The above quote is a great one to live by. It is a quote

# %%
text = """<start_of_turn>user
How does the brain work?<end_of_turn>
<start_of_turn>model"""
device = "cuda:0"
inputs = tokenizer(text, return_tensors="pt").to(device)

outputs = model.generate(**inputs, max_new_tokens=50)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# user
# How does the brain work?
# model
# How does the brain work?SneakyThrows
# SneakyThrows
# SneakyThrows
# SneakyThrows
# SneakyThrows
# SneakyThrows
# SneakyThrows
# SneakyThrows
# SneakyThrows
# SneakyThrows
# SneakyThrows
# SneakyThrows
# SneakyThrows
# SneakyThrows
# SneakyThrows
# SneakyThrows
# SneakyThrows
# SneakyThrows
# SneakyThrows
# SneakyThrows
# SneakyThrows
# SneakyThrows

# %%
text = """<start_of_turn>user
Can you explain how to use WNetAddConnection to map a network share?<end_of_turn>
<start_of_turn>model"""
device = "cuda:0"
inputs = tokenizer(text, return_tensors="pt").to(device)

outputs = model.generate(**inputs, max_new_tokens=50)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# user
# Can you explain how to use WNetAddConnection to map a network share?
# model
# I am using the following code to map a network share:
# WNetAddConnection2(0, "\\\\192.168.1.100", "\\\\192.168.1.

# %%
from datasets import load_dataset

data = load_dataset("ahmed000000000/cybersec")
# Out:
# ...
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
from peft import LoraConfig

lora_config = LoraConfig(
    r=8,
    target_modules=["q_proj", "o_proj", "k_proj", "v_proj", "gate_proj", "up_proj", "down_proj"],
    task_type="CAUSAL_LM",
)

# %%
def formatting_func(example):
    text = f"<start_of_turn>user\n{example['INSTRUCTION'][0]}<end_of_turn> <start_of_turn>model\n{example['RESPONSE'][0]}<end_of_turn>"
    return [text]

# %%
import transformers
from trl import SFTTrainer

trainer = SFTTrainer(
    model=model,
    train_dataset=data["train"],
    args=transformers.TrainingArguments(
        per_device_train_batch_size=1,
        gradient_accumulation_steps=4,
        warmup_steps=2,
        max_steps=150,
        learning_rate=2e-4,
        fp16=True,
        logging_steps=1,
        output_dir="outputs",
        optim="paged_adamw_8bit"
    ),
    peft_config=lora_config,
    formatting_func=formatting_func,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:223: UserWarning: You didn't pass a `max_seq_length` argument to the SFTTrainer, this will default to 1024
#   warnings.warn(
# Map:   0%|          | 0/12408 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:290: UserWarning: You passed a tokenizer with `padding_side` not equal to `right` to the SFTTrainer. This might lead to some unexpected behaviour due to overflow issues when training a model in half-precision. You might consider adding `tokenizer.padding_side = 'right'` to your code.
#   warnings.warn(

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='150' max='150' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [150/150 04:01, Epoch 46/50]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.836400</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.725300</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.663400</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.435900</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.372000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.669600</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.272200</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.682300</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.226400</td>
#     </tr>
#     <tr>
#       <td>10</td>
# ...

# %%
text = """<start_of_turn>user
Can you explain how to use WNetAddConnection to map a network share?<end_of_turn>
<start_of_turn>model"""
device = "cuda:0"
inputs = tokenizer(text, return_tensors="pt").to(device)

outputs = model.generate(**inputs, max_new_tokens=50)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# user
# Can you explain how to use WNetAddConnection to map a network share?
# model
# To use WNetAddConnection to map a network share, first make sure that the computer has access to the network share and that the appropriate network resource is available. Then, use the WNetAddConnection function to establish a connection to the network

# %%
dataset = load_dataset("databricks/databricks-dolly-15k")
# Out:
# ...
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
dataset['train']
# Out:
# Dataset({
#     features: ['instruction', 'context', 'response', 'category'],
#     num_rows: 15011
# })

# %%
text = """<start_of_turn>user
give me a poll question and short answer options regarding equity and representation in AI<end_of_turn>
<start_of_turn>model"""
device = "cuda:0"
inputs = tokenizer(text, return_tensors="pt").to(device)

outputs = model.generate(**inputs, max_new_tokens=50)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# user
# give me a poll question and short answer options regarding equity and representation in AI
# model
# Well, let's think about some examples of equity and representation in AI. One way to promote equity in AI is to have diverse datasets and training algorithms. This helps to ensure that AI models generalize well and don't discriminate against specific groups

# %%
def formatting_func(example):
    text = f"<start_of_turn>user\n{example['instruction'][0]}<end_of_turn> <start_of_turn>model\n{example['response'][0]}<end_of_turn>"
    return [text]

# %%
trainer = SFTTrainer(
    model=model,
    train_dataset=dataset["train"],
    args=transformers.TrainingArguments(
        per_device_train_batch_size=1,
        gradient_accumulation_steps=4,
        warmup_steps=2,
        max_steps=150,
        learning_rate=2e-4,
        fp16=True,
        logging_steps=1,
        output_dir="outputs",
        optim="paged_adamw_8bit"
    ),
    peft_config=lora_config,
    formatting_func=formatting_func,
)

trainer.train()
# Out:
# Map:   0%|          | 0/15011 [00:00<?, ? examples/s]
#     <div>
#
#       <progress value='150' max='150' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [150/150 03:31, Epoch 37/38]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.868400</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.237600</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.241200</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>4.433900</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.413100</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>3.210600</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>3.488900</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>3.870700</td>
#     </tr>
#     <tr>
#       <td>9</td>
# ...

# %%
text = """<start_of_turn>user
give me a poll question and short answer options regarding equity and representation in AI<end_of_turn>
<start_of_turn>model"""
device = "cuda:0"
inputs = tokenizer(text, return_tensors="pt").to(device)

outputs = model.generate(**inputs, max_new_tokens=150)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# user
# give me a poll question and short answer options regarding equity and representation in AI
# model
# Here goes a poll, tell me what should be the representation of AI in a room of 100 people? user
#  rtx 3080, i7 12700k, 16 gb, 100 model AI what should be the number of short term and long term options@[+][ unwarrantable AI? model
# Short term - 5, Long term - 90 dicendo  oled 49A, i7 6700k, 8 gb, 4 model AI what should be the number of short term and long term options@[+][ unwarrantable AI? user
# 60, 90 labd 60,

# %% [markdown]
# # Try fine-tuning on different dataset

# %%
from datasets import load_dataset, concatenate_datasets


import re
def clean_str(example):
  # original format is a list of dictionaries
  # dictionary keys: 'role', 'content'
  clean_message = [each_dict['role']+": "+each_dict['content'] for each_dict in example['messages']]
  # remove the first line since that's just the prompt
  clean_message = clean_message[1:]
  clean_message = '\n'.join(clean_message)
  output = {'prompt': example['prompt'],
            'prompt_id': example['prompt_id'],
            'messages': clean_message
            }
  return output


# data = load_dataset("ahmed000000000/cybersec")
dataset_id1 = "databricks/databricks-dolly-15k"
dataset_id2 = "HuggingFaceH4/no_robots"
# dataset1 = Dataset()
dataset1 = load_dataset(dataset_id1)
dataset2 = load_dataset(dataset_id2)

# apply string cleaning to the no_robots dataset and then combine
formatted_dataset = dataset2.map(clean_str)
# rename the column to match with the no_robots dataset
# dataset1 = dataset1.rename_column('instruction', 'prompt')
formatted_dataset = formatted_dataset.rename_column("messages", "response")
formatted_dataset = formatted_dataset.rename_column("prompt", "instructions")
# combine them
dataset1['train'] = concatenate_datasets([dataset1['train'], formatted_dataset['train_sft']])
# Out:
# ...
# Map:   0%|          | 0/500 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-f2fbebde140a> in <cell line: 33>()
#      31 formatted_dataset = formatted_dataset.rename_column("prompt", "instructions")
#      32 # combine them
# ---> 33 dataset1['train'] = concatenate_datasets([dataset1['train'], formatted_dataset['train_sft']])
#
# /usr/local/lib/python3.10/dist-packages/datasets/dataset_dict.py in __getitem__(self, k)
#      72     def __getitem__(self, k) -> Dataset:
#      73         if isinstance(k, (str, NamedSplit)) or len(self) == 0:
# ---> 74             return super().__getitem__(k)
#      75         else:
#      76             available_suggested_splits = [
#
# KeyError: 'train_sft'

# %%
trainer = SFTTrainer(
    model=model,
    train_dataset=dataset1["train"],
    args=transformers.TrainingArguments(
        per_device_train_batch_size=1,
        gradient_accumulation_steps=4,
        warmup_steps=2,
        max_steps=150,
        learning_rate=2e-4,
        fp16=True,
        logging_steps=1,
        output_dir="outputs",
        optim="paged_adamw_8bit"
    ),
    peft_config=lora_config,
    formatting_func=formatting_func,
)

trainer.train()

# %%
text = """<start_of_turn>user
give me a poll question and short answer options regarding equity and representation in AI<end_of_turn>
<start_of_turn>model"""
device = "cuda:0"
inputs = tokenizer(text, return_tensors="pt").to(device)

outputs = model.generate(**inputs, max_new_tokens=150)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
